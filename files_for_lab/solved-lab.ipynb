# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
display(customer_df.shape)
customer_df.head()
# Out:
# (9134, 24)
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   Total Claim Amount  Vehicle Class Vehicle Size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
customer_df.info
# Out:
# <bound method DataFrame.info of      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# 0     Bachelor           2/24/11         Employed      F   56274  ...
# 1     Bachelor           1/31/11       Unemployed      F       0  ...
# 2     Bachelor           2/19/11         Employed      F   48767  ...
# 3     Bachelor           1/20/11       Unemployed      M       0  ...
# 4     Bachelor            2/3/11         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor           2/10/11         Employed      M   71941  ...
# 9130   College           2/12/11         Employed      F   21604  ...
# 9131  Bachelor            2/6/11       Unemployed      M       0  ...
# 9132   College            2/3/11         Employed      M   21941  ...
# 9133   College           2/14/11       Unemployed      M       0  ...
#
#      Months Since Policy Inception Number of Open Complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]>

# %%
customer_df.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
customer_df.columns = customer_df.columns.str.lower().str.replace(' ', '_')

# Print the DataFrame with renamed columns
print(customer_df.columns)
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'])

# %%
customer_df.isnull()
# Out:
#       customer  state  customer_lifetime_value  response  coverage  education  \
# 0        False  False                    False     False     False      False
# 1        False  False                    False     False     False      False
# 2        False  False                    False     False     False      False
# 3        False  False                    False     False     False      False
# 4        False  False                    False     False     False      False
# ...        ...    ...                      ...       ...       ...        ...
# 9129     False  False                    False     False     False      False
# 9130     False  False                    False     False     False      False
# 9131     False  False                    False     False     False      False
# 9132     False  False                    False     False     False      False
# 9133     False  False                    False     False     False      False
#
#       effective_to_date  employmentstatus  gender  income  ...  \
# 0                 False             False   False   False  ...
# 1                 False             False   False   False  ...
# 2                 False             False   False   False  ...
# 3                 False             False   False   False  ...
# 4                 False             False   False   False  ...
# ...                 ...               ...     ...     ...  ...
# 9129              False             False   False   False  ...
# 9130              False             False   False   False  ...
# 9131              False             False   False   False  ...
# 9132              False             False   False   False  ...
# 9133              False             False   False   False  ...
#
#       months_since_policy_inception  number_of_open_complaints  \
# 0                             False                      False
# 1                             False                      False
# 2                             False                      False
# 3                             False                      False
# 4                             False                      False
# ...                             ...                        ...
# 9129                          False                      False
# 9130                          False                      False
# 9131                          False                      False
# 9132                          False                      False
# 9133                          False                      False
#
#       number_of_policies  policy_type  policy  renew_offer_type  \
# 0                  False        False   False             False
# 1                  False        False   False             False
# 2                  False        False   False             False
# 3                  False        False   False             False
# 4                  False        False   False             False
# ...                  ...          ...     ...               ...
# 9129               False        False   False             False
# 9130               False        False   False             False
# 9131               False        False   False             False
# 9132               False        False   False             False
# 9133               False        False   False             False
#
#       sales_channel  total_claim_amount  vehicle_class  vehicle_size
# 0             False               False          False         False
# 1             False               False          False         False
# 2             False               False          False         False
# 3             False               False          False         False
# 4             False               False          False         False
# ...             ...                 ...            ...           ...
# 9129          False               False          False         False
# 9130          False               False          False         False
# 9131          False               False          False         False
# 9132          False               False          False         False
# 9133          False               False          False         False
#
# [9134 rows x 24 columns]

# %%
def separate_columns(dataframe):
    numerical_columns = dataframe.select_dtypes(include=[np.number])
    categorical_columns = dataframe.select_dtypes(include=['object', 'category'])
    return numerical_columns, categorical_columns

# %%
numerical_df, categorical_df = separate_columns(customer_df)

numerical_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                             0                   1          384.811147
# 1                             0                   8         1131.464935
# 2                             0                   2          566.472247
# 3                             0                   7          529.881344
# 4                             0                   1          138.130879
# ...                         ...                 ...                 ...
# 9129                          0                   2          198.234764
# 9130                          0                   1          379.200000
# 9131                          3                   2          790.784983
# 9132                          0                   3          691.200000
# 9133                          0                   1          369.600000
#
# [9134 rows x 8 columns]

# %%
correlation_matrix = numerical_df.corr()

# %%
highest_correlation = correlation_matrix.max().max()
variable_pair = correlation_matrix.stack().idxmax()

# %%
variable_pair
# Out:
# ('customer_lifetime_value', 'customer_lifetime_value')

# %%
def separate_continuous_discrete(df, unique_threshold=36):
    continuous_cols = []
    discrete_cols = []

    for col in df.columns:
        if pd.api.types.is_numeric_dtype(df[col]):
            unique_values = df[col].nunique()
            if unique_values <= unique_threshold:
                discrete_cols.append(col)
            else:
                continuous_cols.append(col)

    continuous_df = df[continuous_cols]
    discrete_df = df[discrete_cols]

    return continuous_df, discrete_df

# %%
continuous_df, discrete_df = separate_continuous_discrete(customer_df)

# %%
continuous_df, discrete_df = separate_continuous_discrete(customer_df, unique_threshold=50)

# %%
def create_barplot(discrete_df):
    num_cols = len(discrete_df.columns)
    fig, axes = plt.subplots(num_cols, 1, figsize=(16, 16))

    for i, column in enumerate(discrete_df.columns):
        ax = axes[i]
        sns.countplot(x=column, data=discrete_df, ax=ax)
        ax.set_xlabel(column)
        ax.set_ylabel('Count')
        ax.set_title(f'Bar Plot of {column}')

    plt.tight_layout()
    plt.show()

# %%
create_barplot(discrete_df)

# %%
def create_histograms(continuous_df):
    plt.figure(figsize=(16, 16))
    num_cols = continuous_df.select_dtypes(include=['float', 'int']).columns
    num_cols_count = len(num_cols)
    plot_rows = int(num_cols_count / 2) + (num_cols_count % 2 > 0)

    for i, col in enumerate(num_cols):
        plt.subplot(plot_rows, 2, i+1)
        sns.histplot(data=continuous_df, x=col, kde=True)
        plt.xlabel(col)
        plt.ylabel('Count')

    plt.tight_layout()
    plt.show()

# %%
create_histograms(continuous_df)

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=continuous_df)
plt.title("Box Plot of Continuous Data")
plt.show()

# %%
def plot_outliers(dataframe):
    fig, ax = plt.subplots(figsize=(10, 6))

    dataframe.boxplot(ax=ax)

    ax.set_title('Box Plot of Continuous Variables')
    ax.set_ylabel('Value')

    plt.xticks(rotation=45)

    plt.show()

# %%
plot_outliers(continuous_df)

# %% [markdown]
# Lab Cleaning Categorical Data

# %%
def plot_categorical_columns(df):
    categorical_cols = df.select_dtypes(include='object').columns
    
    for col in categorical_cols:
        if df[col].nunique() >= 6:
            plt.figure(figsize=(8, 6))
            sns.countplot(y=col, data=df, order=df[col].value_counts().index)
        else:
            plt.figure(figsize=(6, 6))
            sns.countplot(x=col, data=df, order=df[col].value_counts().index)
            
        plt.title(f'Countplot of {col}')
        plt.show()

# %%
plot_categorical_columns(customer_df)

# %%
customer_df = customer_df.drop("policy_type", axis=1)

# %%
def transform_policy(policy):
    if policy.startswith("L1"):
        return "L1"
    elif policy.startswith("L2"):
        return "L2"
    else:
        return "L3"

# %%
customer_df["policy"] = customer_df["policy"].apply(transform_policy)

# %%
customer_df["policy"]
# Out:
# 0       L3
# 1       L3
# 2       L3
# 3       L3
# 4       L3
#         ..
# 9129    L3
# 9130    L3
# 9131    L3
# 9132    L3
# 9133    L3
# Name: policy, Length: 9134, dtype: object

# %%
customer_df
# Out:
#      customer       state  customer_lifetime_value  response  coverage  \
# 0     BU79786  Washington              2763.519279         0     Basic
# 1     QZ44356     Arizona              6979.535903         0  Extended
# 2     AI49188      Nevada             12887.431650         0   Premium
# 3     WW63253  California              7645.861827         0     Basic
# 4     HB64268  Washington              2813.692575         0     Basic
# ...       ...         ...                      ...       ...       ...
# 9129  LA72316  California             23405.987980         0     Basic
# 9130  PK87824  California              3096.511217         1  Extended
# 9131  TD14365  California              8163.890428         0  Extended
# 9132  UP19263  California              7524.442436         0  Extended
# 9133  Y167826  California              2611.836866         0  Extended
#
#      education effective_to_date employmentstatus  gender  income  ... policy  \
# 0     Bachelor        2011-02-24         Employed       0   56274  ...     L3
# 1     Bachelor        2011-01-31       Unemployed       0       0  ...     L3
# 2     Bachelor        2011-02-19         Employed       0   48767  ...     L3
# 3     Bachelor        2011-01-20       Unemployed       1       0  ...     L3
# 4     Bachelor        2011-02-03         Employed       1   43836  ...     L3
# ...        ...               ...              ...     ...     ...  ...    ...
# 9129  Bachelor        2011-02-10         Employed       1   71941  ...     L3
# 9130   College        2011-02-12         Employed       0   21604  ...     L3
# 9131  Bachelor        2011-02-06       Unemployed       1       0  ...     L3
# 9132   College        2011-02-03         Employed       1   21941  ...     L3
# 9133   College        2011-02-14       Unemployed       1       0  ...     L3
#
#      renew_offer_type  sales_channel  vehicle_class  vehicle_size  \
# 0              Offer1          Agent   Two-Door Car       Medsize
# 1              Offer3          Agent  Four-Door Car       Medsize
# 2              Offer1          Agent   Two-Door Car       Medsize
# 3              Offer1    Call Center            SUV       Medsize
# 4              Offer1          Agent  Four-Door Car       Medsize
# ...               ...            ...            ...           ...
# 9129           Offer2            Web  Four-Door Car       Medsize
# 9130           Offer1         Branch  Four-Door Car       Medsize
# 9131           Offer1         Branch  Four-Door Car       Medsize
# 9132           Offer3         Branch  Four-Door Car         Large
# 9133           Offer4    Call Center   Two-Door Car       Medsize
#
#       total_claim_amount  coverage_encoded employmentstatus_encoded  \
# 0             384.811147                 1                        2
# 1            1131.464935                 2                        0
# 2             566.472247                 3                        2
# 3             529.881344                 1                        0
# 4             138.130879                 1                        2
# ...                  ...               ...                      ...
# 9129          198.234764                 1                        2
# 9130          379.200000                 2                        2
# 9131          790.784983                 2                        0
# 9132          691.200000                 2                        2
# 9133          369.600000                 2                        0
#
#      location_code_encoded vehicle_size_encoded
# 0                        1                    1
# 1                        1                    1
# 2                        1                    1
# 3                        1                    1
# 4                        2                    1
# ...                    ...                  ...
# 9129                     0                    1
# 9130                     1                    1
# 9131                     1                    1
# 9132                     1                    2
# 9133                     1                    1
#
# [9134 rows x 27 columns]

# %%
plt.figure(figsize=(10, 10))

# Create line plot
sns.lineplot(data=customer_df, x='effective_to_date', y='total_claim_amount')

# Rotate x-axis labels for better readability (optional)
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
df = pd.DataFrame()

effective_to_date = pd.to_datetime([])

# Add columns to the DataFrame
df['effective_to_date'] = effective_to_date
df['day'] = df['effective_to_date'].dt.day
df['day_name'] = df['effective_to_date'].dt.day_name()
df['week'] = df['effective_to_date'].dt.week
df['month'] = df['effective_to_date'].dt.month_name()
df['total_claim_amount'] = 0

# Display the DataFrame
print(df)
# Out:
# Empty DataFrame
# Columns: [effective_to_date, day, day_name, week, month, total_claim_amount]
# Index: []
# C:\Users\duygu\AppData\Local\Temp\ipykernel_14960\4179615007.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['week'] = df['effective_to_date'].dt.week

# %%
aggregated = df.groupby('day_name').sum().round(2)

# Define the correct order of days
list_of_correct_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Reorder the index of the resulting pandas series
reordered = aggregated.reindex(index=list_of_correct_days)

# Print the resulting series
print(reordered)
# Out:
#            day  week  total_claim_amount
# day_name
# Monday     NaN   NaN                 NaN
# Tuesday    NaN   NaN                 NaN
# Wednesday  NaN   NaN                 NaN
# Thursday   NaN   NaN                 NaN
# Friday     NaN   NaN                 NaN
# Saturday   NaN   NaN                 NaN
# Sunday     NaN   NaN                 NaN
# C:\Users\duygu\AppData\Local\Temp\ipykernel_14960\3521065533.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   aggregated = df.groupby('day_name').sum().round(2)

# %%
sns.lineplot(data=reordered)
# Out:
# <Axes: xlabel='day_name'>

# %%
reordered['day'] = pd.to_datetime(reordered['day'])  # Convert claim_date to datetime if it's not already

# Group by day of the week and count the number of claims
claims_by_day = reordered.groupby(reordered['day'].dt.day_name()).size()

print(claims_by_day)
# Out:
# Series([], dtype: int64)
# C:\Users\duygu\AppData\Local\Temp\ipykernel_14960\2110827109.py:5: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   claims_by_day = reordered.groupby(reordered['day'].dt.day_name()).size()

# %%
correct_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
claims_by_day_reordered = claims_by_day.reindex(index=correct_order)

print(claims_by_day_reordered)
# Out:
# day
# Monday      NaN
# Tuesday     NaN
# Wednesday   NaN
# Thursday    NaN
# Friday      NaN
# Saturday    NaN
# Sunday      NaN
# dtype: float64

# %%
medians = claims_by_day_reordered.groupby("day").median()
sorted_medians = medians.sort_values(ascending=False)
sorted_medians
# Out:
# day
# Friday      NaN
# Monday      NaN
# Saturday    NaN
# Sunday      NaN
# Thursday    NaN
# Tuesday     NaN
# Wednesday   NaN
# dtype: float64

# %%
median_data = sorted_medians.groupby('day').median().reset_index()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.barplot( data=median_data, ci=None)
plt.title("Median 'target' by Day of the Week")
plt.xlabel("Day of the Week")
plt.ylabel("Median Target")
plt.show()
# Out:
# C:\Users\duygu\AppData\Local\Temp\ipykernel_14960\3604897519.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot( data=median_data, ci=None)

# %%
# Compute total target column aggregated by month, rounded to two decimals
total_target = df.groupby('month').sum().round(2)

# Define the correct order of index values as a list
list_of_correct_values = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Reorder the index of the resulting series using .reindex()
reordered_total_target = total_target.reindex(index=list_of_correct_values)

# Print the resulting series
print(reordered_total_target)
# Out:
#            day  week  total_claim_amount
# month
# January    NaN   NaN                 NaN
# February   NaN   NaN                 NaN
# March      NaN   NaN                 NaN
# April      NaN   NaN                 NaN
# May        NaN   NaN                 NaN
# June       NaN   NaN                 NaN
# July       NaN   NaN                 NaN
# August     NaN   NaN                 NaN
# September  NaN   NaN                 NaN
# October    NaN   NaN                 NaN
# November   NaN   NaN                 NaN
# December   NaN   NaN                 NaN
# C:\Users\duygu\AppData\Local\Temp\ipykernel_14960\3983859393.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_target = df.groupby('month').sum().round(2)

# %%
def remove_outliers(data, column, thr=3):
    """
    Remove outliers from a numerical continuous column based on a given threshold number of standard deviations from the mean.
    
    Parameters:
        - data (pandas DataFrame): The DataFrame containing the data.
        - column (str): The name of the column to remove outliers from.
        - thr (float): The threshold number of standard deviations from the mean. Default is 3.
        
    Returns:
        - data (pandas DataFrame): The DataFrame with outliers removed.
    """
    mean = np.mean(data[column])
    std = np.std(data[column])
    threshold = thr * std

    data = data[(data[column] >= mean - threshold) & (data[column] <= mean + threshold)]
    
    return data

# %%
continuous_clean_df = remove_outliers(customer_df,'customer_lifetime_value')

# %%
continuous_clean_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# 0     Bachelor        2011-02-24         Employed      F   56274  ...
# 1     Bachelor        2011-01-31       Unemployed      F       0  ...
# 2     Bachelor        2011-02-19         Employed      F   48767  ...
# 3     Bachelor        2011-01-20       Unemployed      M       0  ...
# 4     Bachelor        2011-02-03         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor        2011-02-10         Employed      M   71941  ...
# 9130   College        2011-02-12         Employed      F   21604  ...
# 9131  Bachelor        2011-02-06       Unemployed      M       0  ...
# 9132   College        2011-02-03         Employed      M   21941  ...
# 9133   College        2011-02-14       Unemployed      M       0  ...
#
#      months_since_last_claim months_since_policy_inception  \
# 0                         32                             5
# 1                         13                            42
# 2                         18                            38
# 3                         18                            65
# 4                         12                            44
# ...                      ...                           ...
# 9129                      18                            89
# 9130                      14                            28
# 9131                       9                            37
# 9132                      34                             3
# 9133                       3                            90
#
#       number_of_open_complaints  number_of_policies  policy  renew_offer_type  \
# 0                             0                   1      L3            Offer1
# 1                             0                   8      L3            Offer3
# 2                             0                   2      L3            Offer1
# 3                             0                   7      L3            Offer1
# 4                             0                   1      L3            Offer1
# ...                         ...                 ...     ...               ...
# 9129                          0                   2      L3            Offer2
# 9130                          0                   1      L3            Offer1
# 9131                          3                   2      L3            Offer1
# 9132                          0                   3      L3            Offer3
# 9133                          0                   1      L3            Offer4
#
#       sales_channel total_claim_amount  vehicle_class vehicle_size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [8923 rows x 23 columns]

# %%
concatenated_df = pd.concat([continuous_clean_df, discrete_df, categorical_df], axis=1)

# %%
final_df = concatenated_df.dropna().reset_index(drop=True)
final_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 8918  LA72316  California             23405.987980       No     Basic
# 8919  PK87824  California              3096.511217      Yes  Extended
# 8920  TD14365  California              8163.890428       No  Extended
# 8921  UP19263  California              7524.442436       No  Extended
# 8922  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender   income  ...  \
# 0     Bachelor        2011-02-24         Employed      F  56274.0  ...
# 1     Bachelor        2011-01-31       Unemployed      F      0.0  ...
# 2     Bachelor        2011-02-19         Employed      F  48767.0  ...
# 3     Bachelor        2011-01-20       Unemployed      M      0.0  ...
# 4     Bachelor        2011-02-03         Employed      M  43836.0  ...
# ...        ...               ...              ...    ...      ...  ...
# 8918  Bachelor        2011-02-10         Employed      M  71941.0  ...
# 8919   College        2011-02-12         Employed      F  21604.0  ...
# 8920  Bachelor        2011-02-06       Unemployed      M      0.0  ...
# 8921   College        2011-02-03         Employed      M  21941.0  ...
# 8922   College        2011-02-14       Unemployed      M      0.0  ...
#
#      employmentstatus gender  location_code  marital_status     policy_type  \
# 0            Employed      F       Suburban         Married  Corporate Auto
# 1          Unemployed      F       Suburban          Single   Personal Auto
# 2            Employed      F       Suburban         Married   Personal Auto
# 3          Unemployed      M       Suburban         Married  Corporate Auto
# 4            Employed      M          Rural          Single   Personal Auto
# ...               ...    ...            ...             ...             ...
# 8918         Employed      M          Urban         Married   Personal Auto
# 8919         Employed      F       Suburban        Divorced  Corporate Auto
# 8920       Unemployed      M       Suburban          Single  Corporate Auto
# 8921         Employed      M       Suburban         Married   Personal Auto
# 8922       Unemployed      M       Suburban          Single  Corporate Auto
#
#             policy  renew_offer_type sales_channel  vehicle_class vehicle_size
# 0     Corporate L3            Offer1         Agent   Two-Door Car      Medsize
# 1      Personal L3            Offer3         Agent  Four-Door Car      Medsize
# 2      Personal L3            Offer1         Agent   Two-Door Car      Medsize
# 3     Corporate L2            Offer1   Call Center            SUV      Medsize
# 4      Personal L1            Offer1         Agent  Four-Door Car      Medsize
# ...            ...               ...           ...            ...          ...
# 8918   Personal L1            Offer2           Web  Four-Door Car      Medsize
# 8919  Corporate L3            Offer1        Branch  Four-Door Car      Medsize
# 8920  Corporate L2            Offer1        Branch  Four-Door Car      Medsize
# 8921   Personal L2            Offer3        Branch  Four-Door Car        Large
# 8922  Corporate L3            Offer4   Call Center   Two-Door Car      Medsize
#
# [8923 rows x 41 columns]

# %%
customer_df = customer_df.reindex(columns=[col for col in customer_df.columns if col != 'total_claim_amount'] + ['total_claim_amount'])

# %%
customer_df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# 0     Bachelor           2/24/11         Employed      F   56274  ...
# 1     Bachelor           1/31/11       Unemployed      F       0  ...
# 2     Bachelor           2/19/11         Employed      F   48767  ...
# 3     Bachelor           1/20/11       Unemployed      M       0  ...
# 4     Bachelor            2/3/11         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor           2/10/11         Employed      M   71941  ...
# 9130   College           2/12/11         Employed      F   21604  ...
# 9131  Bachelor            2/6/11       Unemployed      M       0  ...
# 9132   College            2/3/11         Employed      M   21941  ...
# 9133   College           2/14/11       Unemployed      M       0  ...
#
#      Months Since Policy Inception Number of Open Complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %%
customer_df['response'] = customer_df['response'].map({"Yes": 1, "No": 0})

# %%
print(customer_df)
# Out:
#      customer       state  customer_lifetime_value  response  coverage  \
# 0     BU79786  Washington              2763.519279         0     Basic
# 1     QZ44356     Arizona              6979.535903         0  Extended
# 2     AI49188      Nevada             12887.431650         0   Premium
# 3     WW63253  California              7645.861827         0     Basic
# 4     HB64268  Washington              2813.692575         0     Basic
# ...       ...         ...                      ...       ...       ...
# 9129  LA72316  California             23405.987980         0     Basic
# 9130  PK87824  California              3096.511217         1  Extended
# 9131  TD14365  California              8163.890428         0  Extended
# 9132  UP19263  California              7524.442436         0  Extended
# 9133  Y167826  California              2611.836866         0  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# 0     Bachelor           2/24/11         Employed      F   56274  ...
# 1     Bachelor           1/31/11       Unemployed      F       0  ...
# 2     Bachelor           2/19/11         Employed      F   48767  ...
# 3     Bachelor           1/20/11       Unemployed      M       0  ...
# 4     Bachelor            2/3/11         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor           2/10/11         Employed      M   71941  ...
# 9130   College           2/12/11         Employed      F   21604  ...
# 9131  Bachelor            2/6/11       Unemployed      M       0  ...
# 9132   College            2/3/11         Employed      M   21941  ...
# 9133   College           2/14/11       Unemployed      M       0  ...
#
#      months_since_policy_inception number_of_open_complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       number_of_policies     policy_type        policy  renew_offer_type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       sales_channel total_claim_amount  vehicle_class vehicle_size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %%
customer_df['education'] = customer_df['education'].replace(['Master', 'Doctor'], 'Graduate')

# %%
class_counts = customer_df['education'].value_counts()
class_counts
# Out:
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Graduate                1083
# Name: education, dtype: int64

# %%
group_mapping = {
    'Medical Leave': 'Inactive',
    'Disabled': 'Inactive',
    'Retired': 'Inactive'
}

# %%
customer_df['employmentstatus'] = customer_df['employmentstatus'].map(group_mapping).fillna(customer_df['employmentstatus'])

# Display the updated class distribution
print(customer_df['employmentstatus'].value_counts())
# Out:
# Employed      5698
# Unemployed    2317
# Inactive      1119
# Name: employmentstatus, dtype: int64

# %%
gender_mapping = {'M': 1, 'F': 0}

# %%
customer_df['gender'] = customer_df['gender'].map(gender_mapping)

# %%
customer_df['gender']
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 9129    1
# 9130    0
# 9131    1
# 9132    1
# 9133    1
# Name: gender, Length: 9134, dtype: int64

# %%
grouping_dict = {
    'Sports Car': 'Luxury',
    'Luxury SUV': 'Luxury',
    'Luxury Car': 'Luxury'
}

# %%
customer_df['vehicle_class'].replace(grouping_dict, inplace=True)

# %%
print(customer_df['vehicle_class'].value_counts())
# Out:
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Luxury            831
# Name: vehicle_class, dtype: int64

# %%
# !pip install pandas scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\duygu\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: scikit-learn in c:\users\duygu\anaconda3\lib\site-packages (1.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\duygu\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\duygu\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\duygu\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\duygu\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\duygu\anaconda3\lib\site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\duygu\anaconda3\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: six>=1.5 in c:\users\duygu\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
coverage_mapping = {
    'Basic': 1,
    'Extended': 2,
    'Premium': 3
}

encoder = LabelEncoder()
customer_df['coverage_encoded'] = customer_df['coverage'].map(coverage_mapping)
# Out:
#      customer       state  customer_lifetime_value  response  coverage  \
# 0     BU79786  Washington              2763.519279         0     Basic
# 1     QZ44356     Arizona              6979.535903         0  Extended
# 2     AI49188      Nevada             12887.431650         0   Premium
# 3     WW63253  California              7645.861827         0     Basic
# 4     HB64268  Washington              2813.692575         0     Basic
# ...       ...         ...                      ...       ...       ...
# 9129  LA72316  California             23405.987980         0     Basic
# 9130  PK87824  California              3096.511217         1  Extended
# 9131  TD14365  California              8163.890428         0  Extended
# 9132  UP19263  California              7524.442436         0  Extended
# 9133  Y167826  California              2611.836866         0  Extended
#
#      education effective_to_date employmentstatus  gender  income  ...  \
# 0     Bachelor        2011-02-24         Employed       0   56274  ...
# 1     Bachelor        2011-01-31       Unemployed       0       0  ...
# 2     Bachelor        2011-02-19         Employed       0   48767  ...
# 3     Bachelor        2011-01-20       Unemployed       1       0  ...
# 4     Bachelor        2011-02-03         Employed       1   43836  ...
# ...        ...               ...              ...     ...     ...  ...
# 9129  Bachelor        2011-02-10         Employed       1   71941  ...
# 9130   College        2011-02-12         Employed       0   21604  ...
# 9131  Bachelor        2011-02-06       Unemployed       1       0  ...
# 9132   College        2011-02-03         Employed       1   21941  ...
# 9133   College        2011-02-14       Unemployed       1       0  ...
#
#      months_since_policy_inception number_of_open_complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       number_of_policies  policy  renew_offer_type  sales_channel  \
# 0                      1      L3            Offer1          Agent
# 1                      8      L3            Offer3          Agent
# 2                      2      L3            Offer1          Agent
# 3                      7      L3            Offer1    Call Center
# 4                      1      L3            Offer1          Agent
# ...                  ...     ...               ...            ...
# 9129                   2      L3            Offer2            Web
# 9130                   1      L3            Offer1         Branch
# 9131                   2      L3            Offer1         Branch
# 9132                   3      L3            Offer3         Branch
# 9133                   1      L3            Offer4    Call Center
#
#       vehicle_class vehicle_size total_claim_amount coverage_encoded
# 0      Two-Door Car      Medsize         384.811147                1
# 1     Four-Door Car      Medsize        1131.464935                2
# 2      Two-Door Car      Medsize         566.472247                3
# 3               SUV      Medsize         529.881344                1
# 4     Four-Door Car      Medsize         138.130879                1
# ...             ...          ...                ...              ...
# 9129  Four-Door Car      Medsize         198.234764                1
# 9130  Four-Door Car      Medsize         379.200000                2
# 9131  Four-Door Car      Medsize         790.784983                2
# 9132  Four-Door Car        Large         691.200000                2
# 9133   Two-Door Car      Medsize         369.600000                2
#
# [9134 rows x 24 columns]

# %%
print(customer_df['coverage_encoded'].value_counts())
# Out:
# 1    5568
# 2    2742
# 3     824
# Name: coverage_encoded, dtype: int64

# %%
customer_df['employmentstatus_encoded'] = customer_df['employmentstatus'].map({
    'Employed': 2,
    'Inactive': 1,
    'Unemployed': 0
})

# %%
print(customer_df['employmentstatus_encoded'].value_counts())
# Out:
# 2    5698
# 0    2317
# 1    1119
# Name: employmentstatus_encoded, dtype: int64

# %%
encoding_dict = {
    "Urban": 0,
    "Suburban": 1,
    "Rural": 2
}

# %%
customer_df['location_code_encoded'] = customer_df['location_code'].map(encoding_dict)
print(customer_df['location_code_encoded'].value_counts())
# Out:
# 1    5779
# 2    1773
# 0    1582
# Name: location_code_encoded, dtype: int64

# %%
encoding_dict = {'Large': 2, 'Medsize': 1, 'Small': 0}

customer_df['vehicle_size_encoded'] = customer_df['vehicle_size'].map(encoding_dict)

print(customer_df['location_code_encoded'].value_counts())
# Out:
# 1    5779
# 2    1773
# 0    1582
# Name: location_code_encoded, dtype: int64

# %%
categorical_columns = customer_df.select_dtypes(include=['object']).columns

# Create a new dataframe with only the categorical columns
df_categorical = customer_df[categorical_columns]

# Display the dataframe with categorical columns
df_categorical
# Out:
#      customer       state  coverage education employmentstatus location_code  \
# 0     BU79786  Washington     Basic  Bachelor         Employed      Suburban
# 1     QZ44356     Arizona  Extended  Bachelor       Unemployed      Suburban
# 2     AI49188      Nevada   Premium  Bachelor         Employed      Suburban
# 3     WW63253  California     Basic  Bachelor       Unemployed      Suburban
# 4     HB64268  Washington     Basic  Bachelor         Employed         Rural
# ...       ...         ...       ...       ...              ...           ...
# 9129  LA72316  California     Basic  Bachelor         Employed         Urban
# 9130  PK87824  California  Extended   College         Employed      Suburban
# 9131  TD14365  California  Extended  Bachelor       Unemployed      Suburban
# 9132  UP19263  California  Extended   College         Employed      Suburban
# 9133  Y167826  California  Extended   College       Unemployed      Suburban
#
#      marital_status policy renew_offer_type sales_channel  vehicle_class  \
# 0           Married     L3           Offer1         Agent   Two-Door Car
# 1            Single     L3           Offer3         Agent  Four-Door Car
# 2           Married     L3           Offer1         Agent   Two-Door Car
# 3           Married     L3           Offer1   Call Center            SUV
# 4            Single     L3           Offer1         Agent  Four-Door Car
# ...             ...    ...              ...           ...            ...
# 9129        Married     L3           Offer2           Web  Four-Door Car
# 9130       Divorced     L3           Offer1        Branch  Four-Door Car
# 9131         Single     L3           Offer1        Branch  Four-Door Car
# 9132        Married     L3           Offer3        Branch  Four-Door Car
# 9133         Single     L3           Offer4   Call Center   Two-Door Car
#
#      vehicle_size
# 0         Medsize
# 1         Medsize
# 2         Medsize
# 3         Medsize
# 4         Medsize
# ...           ...
# 9129      Medsize
# 9130      Medsize
# 9131      Medsize
# 9132        Large
# 9133      Medsize
#
# [9134 rows x 12 columns]

# %%
# Get the unique values for each categorical nominal column
levels = []
for col in df_categorical.columns:
    if df_categorical[col].dtype == 'object':  # Assuming categorical nominal columns are of type 'object'
        unique_values = df_categorical[col].unique().tolist()
        levels.append(unique_values)

# %%
# Print the levels
for i, col_levels in enumerate(levels):
    print(f"Levels for column {df_categorical.columns[i]}: {col_levels}")
# Out:
# Levels for column customer: ['BU79786', 'QZ44356', 'AI49188', 'WW63253', 'HB64268', 'OC83172', 'XZ87318', 'CF85061', 'DY87989', 'BQ94931', 'SX51350', 'VQ65197', 'DP39365', 'SJ95423', 'IL66569', 'BW63560', 'FV94802', 'OE15005', 'WC83389', 'FL50705', 'ZK25313', 'SV62436', 'YH23384', 'TZ98966', 'HM55802', 'FS42516', 'US89481', 'HO30839', 'GE62437', 'EJ77678', 'SV85652', 'UL64533', 'PF41800', 'AO98601', 'SK67821', 'YV55495', 'KY38074', 'DM79012', 'CM61827', 'WC35801', 'QG25316', 'MB98372', 'IL19217', 'SR38658', 'DH41343', 'HG65722', 'BU27331', 'XM45289', 'KP34198', 'SH90947', 'WE95729', 'PY51963', 'RB69909', 'XR95069', 'FR46645', 'SY17488', 'AP67935', 'FS37417', 'ML29312', 'UB61619', 'CD86811', 'RU83859', 'FG63582', 'NN71951', 'WB37082', 'SM52139', 'FL82372', 'DP45816', 'GW33762', 'RZ33670', 'PY70169', 'MO91628', 'HW87852', 'HB20453', 'BN87372', 'YX23800', 'DZ87709', 'XW13033', 'LN31673', 'OM82309', 'ZU35962', 'VH85817', 'DT85712', 'YJ88573', 'SQ19467', 'HF88410', 'ET79815', 'QC35222', 'CJ15590', 'OI48267', 'JY67916', 'OE75231', 'CZ33664', 'WK30175', 'ON44465', 'TV87155', 'KH48895', 'NZ30757', 'RI22468', 'FZ30935', 'UG93476', 'AB96670', 'XK64261', 'EV68375', 'UN51653', 'TO96662', 'MR52087', 'DE75225', 'EP80820', 'GU99037', 'WI57118', 'YQ74870', 'MQ14219', 'KN20603', 'CR48975', 'JI70886', 'VF72557', 'OX28638', 'SK55033', 'OO88645', 'YT36855', 'CW82151', 'DY22043', 'SH36774', 'EM43724', 'FH85960', 'XA55993', 'GO36627', 'QH48047', 'RB50392', 'UH65059', 'FV21968', 'QA87025', 'TQ13499', 'BU44523', 'MS41162', 'PU25891', 'RB81636', 'SX26335', 'AZ95587', 'DS81757', 'OJ94107', 'LP84436', 'YV64727', 'LM19287', 'ZU18643', 'AZ82578', 'XC67861', 'YC43143', 'EK59571', 'GD83998', 'WA25797', 'PD27940', 'BS77946', 'YM50253', 'NR15332', 'RC62865', 'CC15295', 'KA61892', 'OS94884', 'ND87334', 'ML93326', 'YL74911', 'JP69864', 'HL53154', 'RI78966', 'IC13702', 'BE10809', 'HT87217', 'TH95618', 'TS19868', 'LP45550', 'QR87004', 'OE75747', 'DX91392', 'AB72731', 'RU49126', 'IS12901', 'IX37561', 'HH90090', 'IU25463', 'KC11055', 'PD33979', 'NK71023', 'AB13432', 'OZ97704', 'UF46533', 'XP47431', 'GK73582', 'RV98763', 'II62831', 'XK33449', 'TR85083', 'EO95328', 'EN21086', 'YL83902', 'AZ62651', 'ZW25874', 'EH41854', 'MW70227', 'SL22297', 'RV14138', 'UO62808', 'ZX64745', 'FL34139', 'TS11219', 'XX12304', 'SD64087', 'OY38576', 'BG76355', 'IP66913', 'LE95702', 'KX54357', 'EZ78112', 'XN16891', 'XK31350', 'CC30924', 'IT78748', 'KY33386', 'CO44221', 'LK60013', 'DE21533', 'YS94121', 'UK68427', 'TE49565', 'RA88421', 'KQ51983', 'CD88896', 'YV22553', 'WU14435', 'XV84099', 'RI24911', 'KO26461', 'HI14283', 'PT50227', 'BH36570', 'TX17484', 'CT41158', 'AO87348', 'DE55857', 'LF66923', 'CN24514', 'UW32074', 'HP36979', 'PP40919', 'RO73268', 'HO61691', 'BS13062', 'FO35655', 'HR10526', 'IA63417', 'BH35016', 'PK52952', 'OD76309', 'IL28481', 'GY55092', 'UF33451', 'CF15558', 'JM62924', 'EM66435', 'QX45933', 'JI71369', 'JU93290', 'GU66096', 'UC33108', 'LW93867', 'OU78470', 'XW90265', 'HS67749', 'VZ51506', 'UI64281', 'AE98193', 'AZ74055', 'XS76911', 'AY40674', 'NA12740', 'UA84837', 'DJ51510', 'VM58985', 'OH60605', 'UO98052', 'NC53424', 'LQ13873', 'LA97014', 'NB79936', 'NT89061', 'AF10970', 'ZG48513', 'JQ59145', 'FE84989', 'JT52858', 'MC62068', 'EU27538', 'RH42306', 'US23612', 'WV76014', 'RK96223', 'MF82000', 'FM46980', 'SY56792', 'RF61565', 'IM94808', 'VI14730', 'YR34119', 'RR77985', 'VC22097', 'WV17090', 'TM23514', 'MQ68407', 'GJ59592', 'FY56083', 'UA94723', 'FW91032', 'DE34457', 'HD32044', 'HH30454', 'AH84063', 'QA17596', 'XI41052', 'DI30528', 'SC66359', 'EN61670', 'DQ10761', 'BQ51587', 'JE21522', 'WS47147', 'ZA64638', 'EW38459', 'QW87316', 'IC43478', 'TE34064', 'WU60905', 'YM18992', 'PD55753', 'KU56006', 'MJ69973', 'TW43626', 'XX84133', 'ZW84453', 'HO29524', 'VE89726', 'GE87503', 'PX90263', 'NI17718', 'FY32213', 'RZ13254', 'GN45013', 'UB16654', 'KU84464', 'YH43527', 'RO30676', 'QL59704', 'QH19450', 'HR85211', 'UV54502', 'WB38524', 'CE56187', 'JL19416', 'JZ61422', 'LA13377', 'NC99948',  ...
# Levels for column state: ['Washington', 'Arizona', 'Nevada', 'California', 'Oregon']
# Levels for column coverage: ['Basic', 'Extended', 'Premium']
# Levels for column education: ['Bachelor', 'College', 'Graduate', 'High School or Below']
# Levels for column employmentstatus: ['Employed', 'Unemployed', 'Inactive']
# Levels for column location_code: ['Suburban', 'Rural', 'Urban']
# Levels for column marital_status: ['Married', 'Single', 'Divorced']
# Levels for column policy: ['L3']
# Levels for column renew_offer_type: ['Offer1', 'Offer3', 'Offer2', 'Offer4']
# Levels for column sales_channel: ['Agent', 'Call Center', 'Web', 'Branch']
# Levels for column vehicle_class: ['Two-Door Car', 'Four-Door Car', 'SUV', 'Luxury']
# Levels for column vehicle_size: ['Medsize', 'Small', 'Large']

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', categories='levels')

# %%
encoder
# Out:
# OneHotEncoder(categories='levels', drop='first')
